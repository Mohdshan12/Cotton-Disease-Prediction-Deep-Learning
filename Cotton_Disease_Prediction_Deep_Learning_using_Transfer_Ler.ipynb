# %%
train_path = '/content/drive/MyDrive/CNN DATASET/Cotton Disease/train'
val_path = '/content/drive/MyDrive/CNN DATASET/Cotton Disease/test'

# %%
from tensorflow.keras.layers import Input,Dense,Flatten,Lambda
from tensorflow.keras.models import Model
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.applications.inception_v3 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator,load_img
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob

# %%
IMAGE_SIZE = [224,224]

# %%
inception = InceptionV3(input_shape=IMAGE_SIZE +[3],weights='imagenet',include_top=False)

# %%
for layer in inception.layers:
  layer.trainable = False

# %%
folders = glob('/content/drive/MyDrive/CNN DATASET/Cotton Disease/train/*')

# %%
x = Flatten()(inception.output)

# %%
len(folders)
# Out:
# 4

# %%
prediction = Dense(len(folders),activation='softmax')(x)
model = Model(inputs=inception.input, outputs=prediction)

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_3 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_188 (Conv2D)             (None, 111, 111, 32) 864         input_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_188 (BatchN (None, 111, 111, 32) 96          conv2d_188[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 111, 111, 32) 0           batch_normalization_188[0][0]
# __________________________________________________________________________________________________
# ...

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

test_datagen = ImageDataGenerator(rescale = 1./255)

# %%
training_set = train_datagen.flow_from_directory('/content/drive/MyDrive/CNN DATASET/Cotton Disease/train',
                                                 target_size = (224, 224),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')
# Out:
# Found 1951 images belonging to 4 classes.

# %%
test_set = test_datagen.flow_from_directory('/content/drive/MyDrive/CNN DATASET/Cotton Disease/test',
                                            target_size = (224, 224),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 106 images belonging to 4 classes.

# %%
r = model.fit_generator(
  training_set,
  validation_data=test_set,
  epochs=20,
  steps_per_epoch=len(training_set),
  validation_steps=len(test_set)
)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/20
# 61/61 [==============================] - 777s 13s/step - loss: 6.1772 - accuracy: 0.5671 - val_loss: 0.8605 - val_accuracy: 0.8208
# Epoch 2/20
# 61/61 [==============================] - 35s 582ms/step - loss: 0.5972 - accuracy: 0.8769 - val_loss: 0.3636 - val_accuracy: 0.9057
# Epoch 3/20
# 61/61 [==============================] - 35s 578ms/step - loss: 0.6280 - accuracy: 0.8850 - val_loss: 0.6200 - val_accuracy: 0.9057
# Epoch 4/20
# 61/61 [==============================] - 35s 580ms/step - loss: 0.5092 - accuracy: 0.9085 - val_loss: 0.7021 - val_accuracy: 0.8774
# Epoch 5/20
# ...
